# %%
from pycaret.regression import *
import pandas as pd
from pycaret.classification import *

# %%
address= '/home/moayidzaidi/new/virtualenv/env1/diabetes.csv'
dataset= pd.read_csv(address)

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
classification_setup = setup(data= dataset, target='Outcome',remove_outliers=True,normalize=True,normalize_method='robust',
                            silent = True,session_id = 6563)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_f477f116_1840_11eb_9f71_b34edae701dfrow15_col1,#T_f477f116_1840_11eb_9f71_b34edae701dfrow26_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_f477f116_1840_11eb_9f71_b34edae701df" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f477f116_1840_11eb_9f71_b34edae701dflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f477f116_1840_11eb_9f71_b34edae701dfrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f477f116_1840_11eb_9f71_b34edae701dfrow0_col1" class="data row0 col1" >6563</td>
#             </tr>
#             <tr>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_00416298_1841_11eb_9f71_b34edae701df th {
#           text-align: left;
# ...
